# %% [markdown]
# # Plotting of Evaluation Measurements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from statistics import mean

# %% [markdown]
# ### Measurements Files
#
# **Overtaking (COLREGs)**
# a_star = 'measurements/23-06-20_23-21 overtaking A*'
# rrt = 'measurements/23-06-21_01-57 overtaking RRT'
# d_star = 'measurements/23-06-21_01-46 overtaking D*'
# dwa = 'measurements/23-06-30_03-22 overtaking DWA'
# rvo = 'measurements/23-06-30_03-23 overtaking RVO'
# hybrid = 'measurements/23-06-30_15-35 overtaking Hybrid'
#
# **Crossing (COLREGs)**
# a_star = 'measurements/23-06-20_23-19 crossing A*'
# rrt = 'measurements/23-06-21_01-59 crossing RRT'
# d_star = 'measurements/23-06-21_01-47 crossing D*'
# dwa = 'measurements/23-06-30_01-57 crossing DWA'
# rvo = 'measurements/23-06-30_01-33 crossing RVO'
# hybrid = 'measurements/23-06-29_21-34 crossing Hybrid'
#
# **Head-on**
# a_star = 'measurements/23-06-20_23-16 head-on A*'
# rrt = 'measurements/23-06-21_02-00 head-on RRT'
# d_star = 'measurements/23-06-21_01-49 head-on D*'
# dwa = 'measurements/23-06-30_03-28 head-on DWA'
# rvo = 'measurements/23-06-30_03-24 head-on RVO'
# hybrid = 'measurements/23-06-29_21-36 head-on Hybrid'
#
# **Difficult**
# a_star = 'measurements/23-06-20_23-11 difficult A*'
# rrt = 'measurements/23-06-21_02-01 difficult RRT'
# d_star = 'measurements/23-06-21_01-50 difficult D*'
# dwa = 'measurements/23-06-30_03-31 difficult DWA'
# rvo = 'measurements/23-06-30_03-32 difficult RVO'
# hybrid = 'measurements/23-06-30_15-38 difficult Hybrid'

# %% [markdown]
# Choose the runs that should be loaded.

# %%
a_star = 'measurements/23-06-20_23-16 head-on A*'
rrt = 'measurements/23-06-21_02-00 head-on RRT'
d_star = 'measurements/23-06-21_01-49 head-on D*'
dwa = 'measurements/23-06-30_03-28 head-on DWA'
rvo = 'measurements/23-06-30_03-24 head-on RVO'
hybrid = 'measurements/23-06-29_21-36 head-on Hybrid'

# %% [markdown]
# Load measurements of A*.

# %%
df1 = pd.read_csv(a_star)
df1 = df1.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Load measurements of RRT.

# %%
df2 = pd.read_csv(rrt)
df2 = df2.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Load measurements of DWA.

# %%
df3 = pd.read_csv(dwa)
df3 = df3.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Load measurement of D*.

# %%
df4 = pd.read_csv(d_star)
df4 = df4.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Load measurement of RVO.

# %%
df5 = pd.read_csv(rvo)
df5 = df5.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Load measurement of Hybrid.

# %%
df6 = pd.read_csv(hybrid)
df6 = df6.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Plot the **Runtime Measurements**.

# %%
plt.plot(df1['Runtime'])
plt.plot(df2['Runtime'])
plt.plot(df3['Runtime'])
plt.plot(df4['Runtime'])
plt.plot(df5['Runtime'])
plt.title('Runtime Measurements')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Runtime'])), np.arange(1, len(df1['Runtime'])+1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Runtime (s)')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
plt.plot(df1['Runtime normalised'])
plt.plot(df2['Runtime normalised'])
plt.plot(df3['Runtime normalised'])
plt.plot(df4['Runtime normalised'])
plt.plot(df5['Runtime normalised'])
plt.title('Normalised Runtime Measurements')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Runtime normalised'])), np.arange(1, len(df1['Runtime normalised'])+1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Runtime normalised')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot them just for A* and RRT, so one can distinguish them (OPTIONAL!!!)
plt.plot(df1['Runtime'])
plt.plot(df2['Runtime'])
plt.title('Runtime Measurements')
plt.legend(['A*', 'RRT'], loc='upper right')
plt.xticks(np.arange(len(df1['Runtime'])), np.arange(1, len(df1['Runtime'])+1))  # start x axis with 1
plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Runtime (s)')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %% [markdown]
# Plot the **Length Measurements**.

# %%
plt.plot(df1['Length'])
plt.plot(df2['Length'])
plt.plot(df3['Length'])
plt.plot(df4['Length'])
plt.plot(df5['Length'])
plt.title('Pathlength Measurements')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Length'])), np.arange(1, len(df1['Length'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Length')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
plt.plot(df1['Length normalised'])
plt.plot(df2['Length normalised'])
plt.plot(df3['Length normalised'])
plt.plot(df4['Length normalised'])
plt.plot(df5['Length normalised'])
plt.title('Normalised Pathlength Measurements')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Length normalised'])), np.arange(1, len(df1['Length normalised'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Length normalised')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %% [markdown]
# Plot the **Suboptimality Measurement** (mean deviation from optimal, obstaclefree line between start and goal).

# %%
plt.plot(df1['Suboptimality'])
plt.plot(df2['Suboptimality'])
plt.plot(df3['Suboptimality'])
plt.plot(df4['Suboptimality'])
plt.plot(df5['Suboptimality'])
plt.title('Suboptimality Measurements (mean deviation from optimal path)')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Suboptimality'])), np.arange(1, len(df1['Suboptimality'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Suboptimality')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %% [markdown]
# Plot the **Difference Measurements** (between consecutive paths).

# %%
plt.plot(df1['Difference'])
plt.plot(df2['Difference'])
plt.plot(df3['Difference'])
plt.plot(df4['Difference'])
plt.plot(df5['Difference'])
plt.title('Difference Measurements (between consecutive paths)')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Difference'])), np.arange(1, len(df1['Difference'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Difference')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %% [markdown]
# ### Plot all the basic measurments.

# %%
# One plot to show them all
plt.figure(dpi=150)

plt.subplot(3, 2, 1)
plt.plot(df1['Runtime'])
plt.plot(df2['Runtime'])
plt.plot(df3['Runtime'])
plt.plot(df4['Runtime'])
plt.plot(df5['Runtime'])
plt.title('Runtime')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Runtime'])), np.arange(1, len(df1['Runtime'])+1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Runtime (s)')
plt.grid()

plt.subplot(3, 2, 2)
plt.plot(df1['Runtime normalised'])
plt.plot(df2['Runtime normalised'])
plt.plot(df3['Runtime normalised'])
plt.plot(df4['Runtime normalised'])
plt.plot(df5['Runtime normalised'])
plt.title('Normalised Runtime')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper left')
plt.xticks(np.arange(len(df1['Runtime normalised'])), np.arange(1, len(df1['Runtime normalised'])+1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Runtime normalised')
plt.grid()

plt.subplot(3, 2, 3)
plt.plot(df1['Length'])
plt.plot(df2['Length'])
plt.plot(df3['Length'])
plt.plot(df4['Length'])
plt.plot(df5['Length'])
plt.title('Path length')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Length'])), np.arange(1, len(df1['Length'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Length')
plt.grid()

plt.subplot(3, 2, 4)
plt.plot(df1['Length normalised'])
plt.plot(df2['Length normalised'])
plt.plot(df3['Length normalised'])
plt.plot(df4['Length normalised'])
plt.plot(df5['Length normalised'])
plt.title('Normalised Path length')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='lower left')
plt.xticks(np.arange(len(df1['Length normalised'])), np.arange(1, len(df1['Length normalised'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Length normalised')
plt.grid()

plt.subplot(3, 2, 5)
plt.plot(df1['Difference'])
plt.plot(df2['Difference'])
plt.plot(df3['Difference'])
plt.plot(df4['Difference'])
plt.plot(df5['Difference'])
plt.title('Difference (between consecutive paths)')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper left')
plt.xticks(np.arange(len(df1['Difference'])), np.arange(1, len(df1['Difference'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Difference')
plt.grid()

plt.subplot(3, 2, 6)
plt.plot(df1['Suboptimality'])
plt.plot(df2['Suboptimality'])
plt.plot(df3['Suboptimality'])
plt.plot(df4['Suboptimality'])
plt.plot(df5['Suboptimality'])
plt.title('Suboptimality (mean deviation from optimal path)')
plt.legend(['A*', 'RRT', 'DWA', 'D*', 'RVO'], loc='upper right')
plt.xticks(np.arange(len(df1['Suboptimality'])), np.arange(1, len(df1['Suboptimality'])+1))  # start x axis with 1
plt.xlabel('Pathfinding Run')
plt.ylabel('Suboptimality')
plt.grid()

plt.rcParams['figure.figsize'] = [10, 11.5]
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the **Closest Encounter Measurements**.

# %%
# Create temporary dataframe for A* boxplots
temp_close1 = []
for i in range(len(df1.index)):
    temp_close1.append(df1.loc[i, 'Closest 1':'Closest ' + str(len(df1.filter(like='Closest').columns))].dropna().tolist())

# %%
# Create temporary dataframe for RRT boxplots
temp_close2 = []
for i in range(len(df2.index)):
    temp_close2.append(df2.loc[i, 'Closest 1':'Closest ' + str(len(df2.filter(like='Closest').columns))].dropna().tolist())

# %%
# Create temporary dataframe for DWA boxplots
temp_close3 = []
for i in range(len(df3.index)):
    temp_close3.append(df3.loc[i, 'Closest 1':'Closest ' + str(len(df3.filter(like='Closest').columns))].dropna().tolist())

# %%
# Create temporary dataframe for D* boxplots
temp_close4 = []
for i in range(len(df4.index)):
    temp_close4.append(df4.loc[i, 'Closest 1':'Closest ' + str(len(df4.filter(like='Closest').columns))].dropna().tolist())

# %%
# Create temporary dataframe for RVO boxplots
temp_close5 = []
for i in range(len(df5.index)):
    temp_close5.append(df5.loc[i, 'Closest 1':'Closest ' + str(len(df5.filter(like='Closest').columns))].dropna().tolist())

# %%
df5
# Out:
#     Runtime  Runtime normalised      Length  Length normalised  Difference  \
# 0  0.329462            0.001649  200.477630           1.003329    0.000000
# 1  0.079067            0.000438  180.618588           1.000000    5.380898
# 2  0.252759            0.001569  161.689890           1.003732    1.818954
# 3  0.060206            0.000427  141.139087           1.000000    5.451526
# 4  0.182281            0.001499  122.308109           1.005747    1.326229
# 5  0.043214            0.000423  102.213078           1.000000    6.104186
# 6  0.034483            0.000417   82.683289           1.000000    0.165089
# 7  0.026007            0.000418   62.223571           1.000000    0.162684
# 8  0.015453            0.000370   41.763966           1.000000    0.134672
# 9  0.006557            0.000308   21.304629           1.000000    0.002101
#
#    Suboptimality   Closest 1  Closest 2  Closest 3  Closest 4  ...  \
# 0   4.269347e+00    6.893776   6.894522   6.922618   6.930141  ...
# ...

# %%
# Plot boxplot for A*
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_close1)
closest_enc = plt.plot(range(1, len(df1.index) + 1), df1['Closest 1'], "-", color="tab:blue")
closest_mean = plt.plot(range(1, len(df1.index) + 1), df1['Closeness Mean'], "--", color="tab:blue")
plt.title('10% Closest Encounters Measurements - A*')
plt.legend([closest_mean[0], closest_enc[0]], ['10% Closest Encounters Mean', 'Closest Encounter'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=18)
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for RRT
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_close2)
closest_enc = plt.plot(range(1, len(df2.index) + 1), df2['Closest 1'], "-", color="tab:orange")
closest_mean = plt.plot(range(1, len(df2.index) + 1), df2['Closeness Mean'], "--", color="tab:orange")
plt.title('10% Closest Encounters Measurements - RRT')
plt.legend([closest_mean[0], closest_enc[0]], ['10% Closest Encounters Mean', 'Closest Encounter'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=18)
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for DWA
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_close3)
closest_enc = plt.plot(range(1, len(df3.index) + 1), df3['Closest 1'], "-", color="tab:green")
closest_mean = plt.plot(range(1, len(df3.index) + 1), df3['Closeness Mean'], "--", color="tab:green")
plt.title('10% Closest Encounters Measurements - DWA')
plt.legend([closest_mean[0], closest_enc[0]], ['10% Closest Encounters Mean', 'Closest Encounter'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=18)
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for D*
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_close4)
closest_enc = plt.plot(range(1, len(df4.index) + 1), df4['Closest 1'], "-", color="tab:red")
closest_mean = plt.plot(range(1, len(df4.index) + 1), df4['Closeness Mean'], "--", color="tab:red")
plt.title('10% Closest Encounters Measurements - D*')
plt.legend([closest_mean[0], closest_enc[0]], ['10% Closest Encounters Mean', 'Closest Encounter'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=18)
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for RVO
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_close5)
closest_enc = plt.plot(range(1, len(df5.index) + 1), df5['Closest 1'], "-", color="tab:purple")
closest_mean = plt.plot(range(1, len(df5.index) + 1), df5['Closeness Mean'], "--", color="tab:purple")
plt.title('10% Closest Encounters Measurements - RVO')
plt.legend([closest_mean[0], closest_enc[0]], ['10% Closest Encounters Mean', 'Closest Encounter'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=18)
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot overall closest encounter measurements
plt.plot(df1['Closest 1'], "-", color="tab:blue")
plt.plot(df2['Closest 1'], "-", color="tab:orange")
plt.plot(df3['Closest 1'], "-", color="tab:green")
plt.plot(df4['Closest 1'], "-", color="tab:red")
plt.plot(df5['Closest 1'], "-", color="tab:purple")
plt.plot(df1['Closeness Mean'], "--", color="tab:blue")
plt.plot(df2['Closeness Mean'], "--", color="tab:orange")
plt.plot(df3['Closeness Mean'], "--", color="tab:green")
plt.plot(df4['Closeness Mean'], "--", color="tab:red")
plt.plot(df5['Closeness Mean'], "--", color="tab:purple")
plt.title('10% Closest Encounter Measurements')
plt.legend(['A* Closest Encounter', 'RRT Closest Encounter', 'DWA Closest Encounter', 'D* Closest Encounter', 'RVO Closest Encounter', 
            'A* Closeness Mean', 'RRT Closeness Mean', 'DWA Closeness Mean', 'D* Closeness Mean', 'RVO Closeness Mean'], loc='upper right')
plt.xticks(np.arange(len(df1['Closest 1'])), np.arange(1, len(df1['Closest 1']) + 1))  # start x axis with 1
plt.ylim(bottom=5, top=15)
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.rcParams['figure.figsize'] = [9, 7]
plt.show()

# %% [markdown]
# Plot the **Course Changes Measurement**.

# %%
# Create temporary dataframe for A* boxplots
temp_course1 = []
for i in range(len(df1.index)):
    temp_course1.append(df1.loc[i, 'Change 1':'Change ' + str(len(df1.filter(like='Change').columns))].dropna().tolist())

# %%
# Create temporary dataframe for RRT boxplots
temp_course2 = []
for i in range(len(df2.index)):
    temp_course2.append(df2.loc[i, 'Change 1':'Change ' + str(len(df2.filter(like='Change').columns))].dropna().tolist())

# %%
# Create temporary dataframe for DWA boxplots
temp_course3 = []
for i in range(len(df3.index)):
    temp_course3.append(df3.loc[i, 'Change 1':'Change ' + str(len(df3.filter(like='Change').columns))].dropna().tolist())

# %%
# Create temporary dataframe for D* boxplots
temp_course4 = []
for i in range(len(df4.index)):
    temp_course4.append(df4.loc[i, 'Change 1':'Change ' + str(len(df4.filter(like='Change').columns))].dropna().tolist())

# %%
# Create temporary dataframe for RVO boxplots
temp_course5 = []
for i in range(len(df5.index)):
    temp_course5.append(df5.loc[i, 'Change 1':'Change ' + str(len(df5.filter(like='Change').columns))].dropna().tolist())

# %%
# Plot boxplot for A*
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_course1)
changes_mean = plt.plot(range(1, len(df1.index) + 1), df1['Course Variations Mean'], "-", color="tab:blue")
plt.title('10% Biggest Course Changes - A*')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Change')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for RRT
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_course2)
changes_mean = plt.plot(range(1, len(df2.index) + 1), df2['Course Variations Mean'], "-", color="tab:blue")
plt.title('10% Biggest Course Changes - RRT')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Change')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for DWA
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_course3)
changes_mean = plt.plot(range(1, len(df3.index) + 1), df3['Course Variations Mean'], "-", color="tab:blue")
plt.title('10% Biggest Course Changes - DWA')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Change')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for D*
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_course4)
changes_mean = plt.plot(range(1, len(df4.index) + 1), df4['Course Variations Mean'], "-", color="tab:red")
plt.title('10% Biggest Course Changes - D*')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Change')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot boxplot for RVO
fig = plt.figure(figsize =(6.4, 4.8))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(temp_course5)
changes_mean = plt.plot(range(1, len(df5.index) + 1), df5['Course Variations Mean'], "-", color="tab:purple")
plt.title('10% Biggest Course Changes - RVO')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Change')
plt.grid()
# plt.rcParams['figure.figsize'] = [12, 8]
plt.show()

# %%
# Plot overall course changes measurements
plt.plot(df1['Course Variations Mean'], "-", color="tab:blue")
plt.plot(df2['Course Variations Mean'], "-", color="tab:orange")
plt.plot(df3['Course Variations Mean'], "-", color="tab:green")
plt.plot(df4['Course Variations Mean'], "-", color="tab:red")
plt.plot(df5['Course Variations Mean'], "-", color="tab:purple")
plt.title('10% Biggest Course Changes')
plt.legend(['A* Biggest Course Changes Mean', 'RRT Biggest Course Changes Mean', 'DWA Biggest Course Changes Mean', 'D* Biggest Course Changes Mean',
            'RVO Biggest Course Changes Mean'], loc='upper right')
plt.xticks(np.arange(len(df1['Change 1'])), np.arange(1, len(df1['Change 1']) + 1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Changes')
plt.grid()
plt.rcParams['figure.figsize'] = [9, 7]
plt.show()

# %% [markdown]
# ### Plot all the extreme measurements.

# %%
# This one is for all the extreme measurements
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 15), dpi=150, sharey=False)

# Plot boxplot for A*
plt.subplot(4, 2, 1)
plt.boxplot(temp_close1)
# closest_enc = plt.plot(range(1, len(df1.index) + 1), df1['Closest 1'], "-", color="tab:blue")
closest_mean = plt.plot(range(1, len(df1.index) + 1), df1['Closeness Mean'], "--", color="tab:blue")
plt.title('10% Closest Encounters - A*')
plt.legend([closest_mean[0]], ['10% Closest Encounters Mean'], loc='lower right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=12)

# Plot boxplot for RRT
plt.subplot(4, 2, 2)
plt.boxplot(temp_close2)
# closest_enc = plt.plot(range(1, len(df2.index) + 1), df2['Closest 1'], "-", color="tab:orange")
closest_mean = plt.plot(range(1, len(df2.index) + 1), df2['Closeness Mean'], "--", color="tab:orange")
plt.title('10% Closest Encounters - RRT')
plt.legend([closest_mean[0]], ['10% Closest Encounters Mean'], loc='lower right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=12)

# Plot boxplot for DWA
plt.subplot(4, 2, 3)
plt.boxplot(temp_close3)
# closest_enc = plt.plot(range(1, len(df3.index) + 1), df3['Closest 1'], "-", color="tab:green")
closest_mean = plt.plot(range(1, len(df3.index) + 1), df3['Closeness Mean'], "--", color="tab:green")
plt.title('10% Closest Encounters - DWA')
plt.legend([closest_mean[0]], ['10% Closest Encounters Mean'], loc='lower right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()
plt.ylim(bottom=5, top=12)

# Plot overall closest encounter measurements
plt.subplot(4, 2, 4)
# plt.plot(df1['Closest 1'], "-", color="tab:blue")
# plt.plot(df2['Closest 1'], "-", color="tab:orange")
# plt.plot(df3['Closest 1'], "-", color="tab:green")
plt.plot(df1['Closeness Mean'], "-", color="tab:blue")
plt.plot(df2['Closeness Mean'], "-", color="tab:orange")
plt.plot(df3['Closeness Mean'], "-", color="tab:green")
plt.title('10% Closest Encounters')
plt.legend(['A* Close Mean', 'RRT Close Mean', 'DWA Close Mean'], loc='upper left')
plt.xticks(np.arange(len(df1['Closest 1'])), np.arange(1, len(df1['Closest 1']) + 1))  # start x axis with 1
# plt.ylim(bottom=5, top=15)
plt.xlabel('Pathfinding Run')
plt.ylabel('Closeness')
plt.grid()

# Plot boxplot for A*
plt.subplot(4, 2, 5)
plt.boxplot(temp_course1)
changes_mean = plt.plot(range(1, len(df1.index) + 1), df1['Course Variations Mean'], "--", color="tab:blue")
plt.title('10% Biggest Course Changes - A*')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Changes in °')
plt.grid()

# Plot boxplot for RRT
plt.subplot(4, 2, 6)
plt.boxplot(temp_course2)
changes_mean = plt.plot(range(1, len(df2.index) + 1), df2['Course Variations Mean'], "--", color="tab:orange")
plt.title('10% Biggest Course Changes - RRT')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Changes in °')
plt.grid()

# Plot boxplot for DWA
plt.subplot(4, 2, 7)
plt.boxplot(temp_course3)
changes_mean = plt.plot(range(1, len(df3.index) + 1), df3['Course Variations Mean'], "--", color="tab:green")
plt.title('10% Biggest Course Changes - DWA')
plt.legend([changes_mean[0]], ['10% Biggest Course Changes Mean'], loc='upper right')
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Changes in °')
plt.grid()

# Plot overall course changes measurements
plt.subplot(4, 2, 8)
plt.plot(df1['Course Variations Mean'], "-", color="tab:blue")
plt.plot(df2['Course Variations Mean'], "-", color="tab:orange")
plt.plot(df3['Course Variations Mean'], "-", color="tab:green")
plt.plot(df4['Course Variations Mean'], "-", color="tab:red")
plt.plot(df5['Course Variations Mean'], "-", color="tab:purple")
plt.title('10% Biggest Course Changes')
plt.legend(['A* Changes Mean', 'RRT Changes Mean', 'DWA Changes Mean', 'D* Changes Mean', 'RVO Changes Mean'], loc='upper right')
plt.xticks(np.arange(len(df1['Change 1'])), np.arange(1, len(df1['Change 1']) + 1))  # start x axis with 1
# plt.ylim(bottom=0)
plt.xlabel('Pathfinding Run')
plt.ylabel('Course Changes in °')
plt.grid()

plt.rcParams['figure.figsize'] = [12, 8]
plt.tight_layout()
plt.show()

# %% [markdown]
# # Resulting Paths Plot

# %%
pathdf1 = pd.read_csv(a_star + ' Path')
pathdf2 = pd.read_csv(rrt + ' Path')
pathdf3 = pd.read_csv(dwa + ' Path')
pathdf4 = pd.read_csv(d_star + ' Path')
pathdf5 = pd.read_csv(rvo + ' Path')
pathdf6 = pd.read_csv(hybrid + ' Path')

# %%
# Determine start and target coordinates
sx = pathdf1['X'][0]
sy = pathdf1['Y'][0]
gx = pathdf1['X'][len(pathdf1['X']) - 1]
gy = pathdf1['Y'][len(pathdf1['Y']) - 1]

# %%
# Plot overall course changes measurements
plt.figure(dpi=200)
plt.plot(pathdf1['X'], pathdf1['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf2['X'], pathdf2['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf3['X'], pathdf3['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf4['X'], pathdf4['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf5['X'], pathdf5['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf6['X'], pathdf6['Y'], "-w", linewidth=4, label='_')
plt.plot(pathdf1['X'], pathdf1['Y'], "-", color="tab:blue", label='A*')
plt.plot(pathdf2['X'], pathdf2['Y'], "-", color="tab:orange", label='RRT')
plt.plot(pathdf3['X'], pathdf3['Y'], "-", color="tab:green", label='DWA')
plt.plot(pathdf4['X'], pathdf4['Y'], "-", color="tab:cyan", label='D*')
plt.plot(pathdf5['X'], pathdf5['Y'], "-", color="tab:purple", label='RVO')
plt.plot(pathdf6['X'], pathdf6['Y'], "-.", linewidth=3, color="tab:red", label='Hybrid')
plt.plot(gx, gy, "xk", markersize=10, markeredgewidth=2)
axis_measure = [0, 300, 0, 300]
plt.axis(axis_measure)
img = plt.imread("foerde_cutout.png")
plt.imshow(img, extent=[0, 300, 0, 300])
# plt.title('Resulting Paths of all Algorithms')
plt.legend(loc='upper right')
plt.grid()
plt.rcParams['figure.figsize'] = [7, 7]
plt.show()

# %% [markdown]
# ### Evaluation measurement of the resulting path

# %% [markdown]
# #### Overall Runtime

# %%
df1['Runtime'].sum()  # A* runtime
# Out:
# 0.2367082509881579

# %%
df2['Runtime'].sum()  # RRT runtime
# Out:
# 9.64323050899111

# %%
df3['Runtime'].sum()  # DWA runtime
# Out:
# 112.29600395997113

# %%
df4['Runtime'].sum()  # D* runtime
# Out:
# 63.98439070601307

# %%
df5['Runtime'].sum()  # RVO runtime
# Out:
# 1.0294880760047815

# %%
df6['Runtime'].sum()  # Hybrid runtime
# Out:
# 1.3985691700072491

# %% [markdown]
# #### Overall Path Length

# %%
# A* path length
length1 = 0.0
for i in range(len(pathdf1['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf1['X'][i + 1] - pathdf1['X'][i]) ** 2 + (pathdf1['Y'][i + 1] - pathdf1['Y'][i]) ** 2)
    length1 += temp
length1
# Out:
# 206.95584412271572

# %%
# RRT path length
length2 = 0.0
for i in range(len(pathdf2['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf2['X'][i + 1] - pathdf2['X'][i]) ** 2 + (pathdf2['Y'][i + 1] - pathdf2['Y'][i]) ** 2)
    length2 += temp
length2
# Out:
# 225.9193878183242

# %%
# DWA path length
length3 = 0.0
for i in range(len(pathdf3['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf3['X'][i + 1] - pathdf3['X'][i]) ** 2 + (pathdf3['Y'][i + 1] - pathdf3['Y'][i]) ** 2)
    length3 += temp
length3
# Out:
# 204.8981029436699

# %%
# D* path length
length4 = 0.0
for i in range(len(pathdf4['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf4['X'][i + 1] - pathdf4['X'][i]) ** 2 + (pathdf4['Y'][i + 1] - pathdf4['Y'][i]) ** 2)
    length4 += temp
length4
# Out:
# 205.4558441227157

# %%
# RVO path length
length5 = 0.0
for i in range(len(pathdf5['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf5['X'][i + 1] - pathdf5['X'][i]) ** 2 + (pathdf5['Y'][i + 1] - pathdf5['Y'][i]) ** 2)
    length5 += temp
length5
# Out:
# 200.8812293482831

# %%
# Hybrid path length
length6 = 0.0
for i in range(len(pathdf6['X']) - 1):
    # Calculate Euclidean distance of one path segment
    temp = math.sqrt((pathdf6['X'][i + 1] - pathdf6['X'][i]) ** 2 + (pathdf6['Y'][i + 1] - pathdf6['Y'][i]) ** 2)
    length6 += temp
length6
# Out:
# 201.37330885267085

# %% [markdown]
# #### Overall Suboptimality

# %%
# Slope of optimal path between start and goal
slope = (gy - sy) / (gx - sx)

# %%
# [CHANGE THE DATAFRAME FOR EVERY ALGORITHM INDIVDUALLY!!!]
# The actual suboptimality computation of the given path
suboptimal = []
# Save x and y-values in different variables for calculation clarity
path_x_values = pathdf6['X'].tolist()  # CHANGE HERE
path_y_values = pathdf6['Y'].tolist()  # CHANGE HERE
# Save start and target point in a different format for calculation clarity
x_start = sx
y_start = sy
x_goal = gx
y_goal = gy
# Adjust calculations to direction from start to target
if gx < sx:
    x_start = gx
    y_start = gy
    x_goal = sx
    y_goal = sy
    path_x_values.reverse()
    path_y_values.reverse()
for i in range(1, len(path_x_values) - 1):
    # Rename x and y-value of the actual path point for clarity in the following calculations
    x_path = path_x_values[i]
    y_path = path_y_values[i]
    # Shift the origin of the coordinate system to the current start point
    x_path -= x_start
    y_path -= y_start
    # First calculate the y-value of the ideal path with the x-value from the planners path with the linear equation
    y_ideal = x_path * slope
    # Second calculate the x-value of the ideal path with the y-value from the planners path with the transformed
    # linear equation
    x_ideal = y_path / slope
    # Third calculate the hypotenuse of the intended right triangle
    hypotenuse = math.sqrt((x_path - x_ideal) ** 2 + (y_path - y_ideal) ** 2)
    if hypotenuse > 0:
        # Fourth calculate the catheti of the intended right triangle
        cathetus_a = abs(x_path - x_ideal)
        cathetus_b = abs(y_path - y_ideal)
        # Fifth calculate p and q of the hypotenuse using Euclids cathetus theorem (transformed)
        p = (cathetus_a ** 2) / hypotenuse
        q = (cathetus_b ** 2) / hypotenuse
        # Six calculate the height of the right triangle by the geometric mean theorem
        heigth = math.sqrt(p * q)
        # Then save the result
        suboptimal.append(heigth)
mean(suboptimal)
# Out:
# 5.724143498259503

# %% [markdown]
# #### Overall Closeness Mean

# %%
df1['Closeness Mean'].mean()  # A*
# Out:
# 37.987198096674824

# %%
df2['Closeness Mean'].mean()  # RRT
# Out:
# 39.5620547368404

# %%
df3['Closeness Mean'].mean()  # DWA
# Out:
# 31.799843582506448

# %%
df4['Closeness Mean'].mean()  # D*
# Out:
# 38.2004416137609

# %%
df5['Closeness Mean'].mean()  # RVO
# Out:
# 27.780664656405037

# %%
df6['Closeness Mean'].mean()  # Hybrid
# Out:
# 43.07731576488443

# %% [markdown]
# #### Overall Biggest Course Changes Mean

# %%
# [CHANGE THE DATAFRAME FOR EVERY ALGORITHM INDIVIDUALLY!!!]
path_x_values = pathdf6['X'].tolist()  # CHANGE HERE
path_y_values = pathdf6['Y'].tolist()  # CHANGE HERE
temp = []
templist = []
for i in range(len(path_x_values) - 1):
    # Calculate the angle (only if segments aren't nearly the same; could be because the resulting path is puzzled together)
    if abs(path_x_values[i + 1] - path_x_values[i]) > 0.0000001 or abs(path_y_values[i + 1] - path_y_values[i]) > 0.0000001:
        angle = math.degrees(math.atan2((path_x_values[i + 1] - path_x_values[i]), 
                        (path_y_values[i + 1] - path_y_values[i])))
        # Save course change measurement
        temp.append(angle)
    if len(temp) > 1:
        course_change = abs(temp[-1] - temp[-2])
        # To acommodate math.atan2(), and realistic angle woulf never be greater than 180°; 
        # otherwise ASV could just turn the other way around
        if course_change > 180:
            course_change = 360 - course_change
        templist.append(course_change)
templist.sort(reverse=True)
# Calculate the mean of the biggest 10% of course changes 
target = len(path_x_values) / 10
templist = templist[:int(target)]
# Filter all course changes that are no real changes
while 0 in templist:
    templist.remove(0)
mean(templist)
# Out:
# 0.08191206907338584
